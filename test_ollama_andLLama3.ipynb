# %%
# Import SmartScraperGraph from scrapegraphai.graphs module
from scrapegraphai.graphs import SmartScraperGraph
import nest_asyncio  # Import nest_asyncio module for asynchronous operations
nest_asyncio.apply()  # Apply nest_asyncio to resolve any issues with asyncio event loop

# Configuration dictionary for the graph
graph_config = {
    "llm": {
        "model": "llama3-8b-8192",  # Specify the model for the llm
        "temperature": 0,  # Set temperature parameter for llm
        "format": "json",  # Specify the output format as JSON for Ollama
        "base_url": "http://localhost:11434",  # Set the base URL for Ollama
    },
    "embeddings": {
        "model": "ollama/nomic-embed-text",  # Specify the model for embeddings
        "base_url": "http://localhost:11434",  # Set the base URL for Ollama
    },
    "verbose": True,  # Enable verbose mode for debugging purposes
}

# Initialize SmartScraperGraph with prompt, source, and configuration
smart_scraper_graph = SmartScraperGraph(
    #prompt="List all the content",  # Set prompt for scraping
    prompt="List me all the projects with their descriptions",
    # Source URL or HTML content to scrape
    #source="https://github.com/InsightEdge01",
    source="https://perinim.github.io/projects",
    config=graph_config  # Pass the graph configuration
)

# Run the SmartScraperGraph and store the result
result = smart_scraper_graph.run()

# Print the result
print(result)

# Prettify the result and display the JSON
import json

output = json.dumps(result, indent=2)  # Convert result to JSON format with indentation

line_list = output.split("\n")  # Split the JSON string into lines

# Print each line of the JSON separately
for line in line_list:
    print(line)
# Out:
# --- Executing Fetch Node ---
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 32
#      22 smart_scraper_graph = SmartScraperGraph(
#      23     #prompt="List all the content",  # Set prompt for scraping
#      24     prompt="List me all the projects with their descriptions",
#    (...)
#      28     config=graph_config  # Pass the graph configuration
#      29 )
#      31 # Run the SmartScraperGraph and store the result
# ---> 32 result = smart_scraper_graph.run()
#      34 # Print the result
#      35 print(result)
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\scrapegraphai\graphs\smart_scraper_graph.py:112, in SmartScraperGraph.run(self)
#     104 """
#     105 Executes the scraping process and returns the answer to the prompt.
#     106
#     107 Returns:
#     108     str: The answer to the prompt.
#     109 """
#     111 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 112 self.final_state, self.execution_info = self.graph.execute(inputs)
#     114 return self.final_state.get("answer", "No answer found.")
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\scrapegraphai\graphs\base_graph.py:107, in BaseGraph.execute(self, initial_state)
#     104 current_node = index
#     106 with get_openai_callback() as cb:
# --> 107     result = current_node.execute(state)
#     108     node_exec_time = time.time() - curr_time
#     109     total_exec_time += node_exec_time
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\scrapegraphai\nodes\fetch_node.py:156, in FetchNode.execute(self, state)
#     153     loader_kwargs = self.node_config.get("loader_kwargs", {})
#     155 loader = ChromiumLoader([source], headless=self.headless, **loader_kwargs)
# --> 156 document = loader.load()
#     158 title, minimized_body, link_urls, image_urls = cleanup_html(str(document[0].page_content), source)
#     159 parsed_content = f"Title: {title}, Body: {minimized_body}, Links: {link_urls}, Images: {image_urls}"
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\langchain_core\document_loaders\base.py:29, in BaseLoader.load(self)
#      27 def load(self) -> List[Document]:
#      28     """Load data into Document objects."""
# ---> 29     return list(self.lazy_load())
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\scrapegraphai\docloaders\chromium.py:103, in ChromiumLoader.lazy_load(self)
#     100 scraping_fn = getattr(self, f"ascrape_{self.backend}")
#     102 for url in self.urls:
# --> 103     html_content = asyncio.run(scraping_fn(url))
#     104     metadata = {"source": url}
#     105     yield Document(page_content=html_content, metadata=metadata)
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File d:\Data Science\LLama3 Project\venv\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File d:\Data Science\LLama3 Project\venv\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\scrapegraphai\docloaders\chromium.py:76, in ChromiumLoader.ascrape_playwright(self, url)
#      74 results = ""
#      75 async with async_playwright() as p:
# ---> 76     browser = await p.chromium.launch(
#      77         headless=self.headless, proxy=self.proxy, **self.browser_config
#      78     )
#      79     try:
#      80         page = await browser.new_page()
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\playwright\async_api\_generated.py:13882, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   13767 async def launch(
#   13768     self,
#   13769     *,
#    (...)
#   13790     ] = None
#   13791 ) -> "Browser":
#   13792     """BrowserType.launch
#   13793
#   13794     Returns the browser instance.
#    (...)
#   13878     Browser
#   13879     """
#   13881     return mapping.from_impl(
# > 13882         await self._impl_obj.launch(
#   13883             executablePath=executable_path,
#   13884             channel=channel,
#   13885             args=mapping.to_impl(args),
#   13886             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   13887             handleSIGINT=handle_sigint,
#   13888             handleSIGTERM=handle_sigterm,
#   13889             handleSIGHUP=handle_sighup,
#   13890             timeout=timeout,
#   13891             env=mapping.to_impl(env),
#   13892             headless=headless,
#   13893             devtools=devtools,
#   13894             proxy=proxy,
#   13895             downloadsPath=downloads_path,
#   13896             slowMo=slow_mo,
#   13897             tracesDir=traces_dir,
#   13898             chromiumSandbox=chromium_sandbox,
#   13899             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   13900         )
#   13901     )
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\playwright\_impl\_browser_type.py:94, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      91 params = locals_to_params(locals())
#      92 normalize_launch_params(params)
#      93 browser = cast(
# ---> 94     Browser, from_channel(await self._channel.send("launch", params))
#      95 )
#      96 self._did_launch_browser(browser)
#      97 return browser
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\playwright\_impl\_connection.py:59, in Channel.send(self, method, params)
#      58 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 59     return await self._connection.wrap_api_call(
#      60         lambda: self.inner_send(method, params, False)
#      61     )
#
# File d:\Data Science\LLama3 Project\venv\lib\site-packages\playwright\_impl\_connection.py:513, in Connection.wrap_api_call(self, cb, is_internal)
#     511     return await cb()
#     512 except Exception as error:
# --> 513     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     514 finally:
#     515     self._api_zone.set(None)
#
# Error: BrowserType.launch: Executable doesn't exist at C:\Users\PC\AppData\Local\ms-playwright\chromium-1112\chrome-win\chrome.exe
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝
